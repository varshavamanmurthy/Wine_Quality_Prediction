# %% [markdown]
# ## Importing all the necessary packages ##

# %%
# This is classification and regression problem where we have to predict the quality of wine(red & white) based on a set of values for features

import pandas as pd# data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np # linear algebra

# %% [markdown]
# ## Reading the white-wine data ##

# %%
# Reading the white-wine csv file

df_white_wine= pd.read_csv("/Users/revasmac/Desktop/Data245_ML/winequality-white.csv")
df_white_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %% [markdown]
# ## Data Preprocessing for white-wine ##

# %%
# Checking for NULL values

print(df_white_wine.isnull().values.any())
# Out:
# False

# %%
# summary
df_white_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %%
# Checking for categorical values

print(df_white_wine.shape)

df_white_wine.info()
# Out:
# (4898, 12)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
# Checking for duplicate rows

df_white_wine=df_white_wine.drop_duplicates()
df_white_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 6               6.2              0.32         0.16             7.0      0.045
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 6                    30.0                 136.0  0.99490  3.18       0.47
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 6         9.6        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [3961 rows x 12 columns]

# %%
# Creating a copy of the white-wine dataset so that the original dataset will not change.

df_white_wine_cf = df_white_wine.copy()
df_white_wine_cf
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 6               6.2              0.32         0.16             7.0      0.045
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 6                    30.0                 136.0  0.99490  3.18       0.47
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 6         9.6        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [3961 rows x 12 columns]

# %%
# Adding "_" in between all the columns of white-wine dataset

df_white_wine_cf.columns = df_white_wine.columns.str.replace(" ", "_")
df_white_wine_cf
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 6               6.2              0.32         0.16             7.0      0.045
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 6                    30.0                 136.0  0.99490  3.18       0.47
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 6         9.6        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [3961 rows x 12 columns]

# %% [markdown]
# ## Converting into binary classification ##

# %%
# For binary classification of the target variable we are adding one new column named "quality_rank" and making it "0" for quality between (1-6) and "1" for quality (7&8)

df_white_wine_cf['quality_rank'] = [1 if x >= 7 else 0 for x in df_white_wine_cf['quality']]
df_white_wine_cf
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 6               6.2              0.32         0.16             7.0      0.045
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 6                    30.0                 136.0  0.99490  3.18       0.47
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  quality_rank
# 0         8.8        6             0
# 1         9.5        6             0
# 2        10.1        6             0
# 3         9.9        6             0
# 6         9.6        6             0
# ...       ...      ...           ...
# 4893     11.2        6             0
# 4894      9.6        5             0
# 4895      9.4        6             0
# 4896     12.8        7             1
# 4897     11.8        6             0
#
# [3961 rows x 13 columns]

# %%
# Separating the feature variables and target variable

X_white = df_white_wine_cf.drop(['quality','quality_rank'], axis = 1)
y_white = df_white_wine_cf['quality_rank']

# %%
# See proportion of wines based on quality_rank for making sure that data is not imbalanced.

df_white_wine_cf['quality_rank'].value_counts()
# Out:
# 0    3136
# 1     825
# Name: quality_rank, dtype: int64

# %% [markdown]
# #### Based on above result we can see that it's fair enough to fit the data into model!!!####

# %% [markdown]
# ## Preparing data for modeling ##

# %% [markdown]
# #### Standardizing feature variables in order to equalize the range of the data.####

# %%
# Normalize feature variables

from sklearn.preprocessing import StandardScaler

X_features_white = X_white 
X_white = StandardScaler().fit_transform(X_white)

# %% [markdown]
# ## Split data ##

# %%
# Splitting the data into 70% training and 30% test 

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_white, y_white, test_size=0.3, random_state=0)

# %% [markdown]
# ## Classification model for white-wine ##

# %%
#Import svm model
from sklearn import svm

#Create a svm Classifier
white_clf = svm.SVC(kernel='poly') # Polynomial Kernel

#Train the model using the training sets
white_clf.fit(X_train, y_train)

#Predict the response for test dataset
white_y_pred = white_clf.predict(X_test)

#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, white_y_pred))
# Out:
# Accuracy: 0.8200168208578638

# %%
#check the areaUnderROC value
from sklearn.metrics import roc_auc_score
print("areaUnderROC:",metrics.roc_auc_score(y_test, white_y_pred))
# Out:
# areaUnderROC: 0.7642401621729787

# %% [markdown]
# ## Regression model for white-wine ##

# %%
#Import svm model
from sklearn import svm

#Create a svm Regression
white_rng = svm.SVR(kernel='poly') # polynomial Kernel

#Train the model using the training sets
white_rng.fit(X_train, y_train)

#Predict the response for test dataset
white_y_pred = white_rng.predict(X_test)
white_y_pred
# Out:
# array([ 5.08668154e-02,  4.16145629e-02,  7.48933663e-02, -3.52391095e+00,
#         1.60218626e-01,  1.04271982e-01,  6.98540104e-02, -4.27862485e-02,
#         1.78216544e-02,  3.21556363e-01,  1.77054361e-01,  8.31296163e-01,
#        -1.02876124e-03,  5.08524005e-02,  4.13830977e-01,  5.20655145e-01,
#        -8.33092896e-04,  7.92472097e-03, -1.73536445e+00,  1.42467477e-01,
#         6.30760656e-02,  1.37864926e-01,  5.92991741e-01, -1.89474464e-01,
#         2.79077561e-01,  1.06150839e+00,  8.79664078e-02,  2.69993246e-01,
#         1.16523393e-01, -9.92217801e-02, -4.15761581e-02,  1.03789452e-01,
#        -3.89494504e-03,  1.03770023e-01,  2.27881352e+00,  1.55920687e-01,
#         1.09603245e-01, -2.72541205e+00,  6.63376714e-02, -5.39361700e-01,
#         7.84186898e-02, -1.45184886e-02,  1.69474586e-01,  7.04397367e-02,
#         2.37937828e-01,  6.70027863e-02,  4.25748316e-02,  8.76208359e-02,
#         1.08188220e-01,  8.64229088e-02,  2.05051811e-01,  5.68677261e-02,
#        -4.37494766e+00,  3.72423910e-02,  5.96581612e-02,  2.00172316e-01,
#         8.73808504e-02,  3.59955272e-01,  7.46371243e-02,  1.51989092e+00,
#        -1.33156445e-01,  9.92379774e-02,  2.44688139e-01,  2.77482423e-03,
#         1.53233075e-01,  7.32783955e-02,  7.30278941e-01,  2.55733423e-01,
#        -1.02314133e-01, -1.46522071e-01,  5.01990580e-02,  2.73181343e-02,
#        -2.37248128e-03,  1.30350417e-01,  1.97226771e-01,  1.50302446e-01,
#         8.11920713e-02,  7.34577836e-02,  1.33886221e-01, -7.57779182e-01,
#         1.66349453e-02,  9.53146621e-02,  1.63691064e-01,  4.58113199e-01,
#         1.24164529e-01, -2.99295960e-01,  8.02498017e-02,  1.73629505e-01,
#         9.25595454e-02,  9.12641034e-02,  1.61133118e-01, -1.33206604e-01,
#         4.86064659e-02,  3.04934481e-02,  4.97065238e-02,  3.03885340e-02,
#         1.56484655e-01, -3.88326113e-02, -1.53825845e-02,  1.87834594e-01,
#         2.43081260e-01, -5.52663164e-02,  1.79316327e-01,  1.51440075e-01,
#        -4.64837444e-01,  1.27050894e-01, -4.55214487e-02,  3.47935751e-02,
#         8.57405696e-02,  1.50205273e-01, -1.44314436e-01,  8.01075121e-02,
#         4.89771794e-02,  6.47174496e-02,  4.87731577e-02, -1.03088890e-01,
#         1.83055050e-01,  1.25949172e-01,  1.99110336e-01,  9.55378540e-02,
#        -4.11784064e-03,  1.20969901e-01,  1.83300334e-01,  8.08392873e-02,
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
print(" The r-square_value",metrics.r2_score(y_test, white_y_pred))
# Out:
#  The r-square_value -1.1900635341210797

# %%
print(" The rmse_score:",metrics.mean_squared_error(y_test, white_y_pred, squared=False))
# Out:
#  The rmse_score: 0.5967538194983792

# %% [markdown]
# ## Reading the red-wine data ##

# %%
# Reading the red-wine csv file

df_red_wine= pd.read_csv("/Users/revasmac/Desktop/Data245_ML/winequality-red.csv")
df_red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %% [markdown]
# ## Data Preprocessing for red-wine ##

# %%
# Checking for NULL values

print(df_red_wine.isnull().values.any())
# Out:
# False

# %%
# summary
df_red_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
# Checking for categorical values

print(df_red_wine.shape)

df_red_wine.info()
# Out:
# (1599, 12)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# Checking for duplicate rows

df_red_wine=df_red_wine.drop_duplicates()
df_red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 5                    13.0                  40.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 5         9.4        5
# ...       ...      ...
# 1593      9.5        6
# 1594     10.5        5
# 1595     11.2        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1359 rows x 12 columns]

# %%
# Creating a copy of the red wine dataset so that the original dataset will not change.

df_red_wine_cf = df_red_wine.copy()
df_red_wine_cf
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 5                    13.0                  40.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 5         9.4        5
# ...       ...      ...
# 1593      9.5        6
# 1594     10.5        5
# 1595     11.2        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1359 rows x 12 columns]

# %%
# Adding "_" in between all the columns of red wine dataset

df_red_wine_cf.columns = df_red_wine.columns.str.replace(" ", "_")
df_red_wine_cf
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 5                    13.0                  40.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 5         9.4        5
# ...       ...      ...
# 1593      9.5        6
# 1594     10.5        5
# 1595     11.2        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1359 rows x 12 columns]

# %%
# For binary classification of the target variable we are adding one new column named "quality_rank" and making it "0" for quality between (1-6) and "1" for quality (7&8)

df_red_wine_cf['quality_rank'] = [1 if x >= 7 else 0 for x in df_red_wine_cf['quality']]
df_red_wine_cf
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 5                    13.0                  40.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality  quality_rank
# 0         9.4        5             0
# 1         9.8        5             0
# 2         9.8        5             0
# 3         9.8        6             0
# 5         9.4        5             0
# ...       ...      ...           ...
# 1593      9.5        6             0
# 1594     10.5        5             0
# 1595     11.2        6             0
# 1597     10.2        5             0
# 1598     11.0        6             0
#
# [1359 rows x 13 columns]

# %%
# Separating the feature variables and target variable

X_red = df_red_wine_cf.drop(['quality','quality_rank'], axis = 1)
y_red = df_red_wine_cf['quality_rank']

# %%
# See proportion of wines based on quality_rank for making sure that data is not imbalanced.

df_red_wine_cf['quality_rank'].value_counts()
# Out:
# 0    1175
# 1     184
# Name: quality_rank, dtype: int64

# %% [markdown]
# #### Based on above result we can see that it's fair enough to fit the data into model!!!####

# %% [markdown]
# ## Preparing data for modeling ##

# %% [markdown]
# #### Standardizing feature variables in order to equalize the range of the data.####

# %%
# Normalize feature variables

from sklearn.preprocessing import StandardScaler

X_features_red = X_red 
X_red = StandardScaler().fit_transform(X_red)

# %% [markdown]
# ## Split data ##

# %%
# Splitting the data into training and test dataset.

from sklearn.model_selection import train_test_split
X_true, X_test, y_true, y_test = train_test_split(X_red, y_red, test_size=.30, random_state=0)

# %% [markdown]
# ## Classification Model for red-wine ##

# %%
#Import svm model
from sklearn import svm

#Create a svm Classifier
red_clf = svm.SVC(kernel='poly') # Polynomial Kernel

#Train the model using the training sets
red_clf.fit(X_true, y_true)

#Predict the response for test dataset
red_y_pred = red_clf.predict(X_test)

#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, red_y_pred))
# Out:
# Accuracy: 0.8186274509803921

# %%
#check the areaUnderROC value
from sklearn.metrics import roc_auc_score
print("areaUnderROC:",metrics.roc_auc_score(y_test, red_y_pred))
# Out:
# areaUnderROC: 0.5424430641821946

# %% [markdown]
# ## Regression model for red-wine ##

# %%
#Import svm model
from sklearn import svm

#Create a svm Regression
red_rng = svm.SVR(kernel='poly') # polynomial Kernel

#Train the model using the training sets
red_rng.fit(X_true, y_true)

#Predict the response for test dataset
red_y_pred = red_rng.predict(X_test)
red_y_pred
# Out:
# array([ 2.69378672e-01,  9.52444993e-02,  6.20838396e-02, -6.63530363e-01,
#         9.50933331e-02,  3.85705145e-02,  9.60101868e-02,  4.70620672e-02,
#        -1.09826153e-02,  6.56012961e-02,  4.38202495e-02, -1.11641119e-01,
#        -2.08607948e-02,  1.84973551e-02,  6.24126877e-01,  4.28618662e-02,
#         2.52382245e-01, -5.15243311e-03, -1.04804926e-01,  9.84000287e-02,
#        -9.05653783e-02, -9.84880558e-02,  2.73906113e-02, -1.68202938e-01,
#         3.12580234e-02,  3.97906177e+00,  3.06344142e-01,  1.45092622e-01,
#        -1.59688488e-02, -1.50592374e-01,  2.43924299e-02, -1.63995380e-02,
#        -4.04474344e-02,  6.00609495e-02,  3.49707303e-01,  3.11573128e-03,
#        -6.69180257e-03,  1.83616729e+00,  6.15808827e-02, -1.32817046e+00,
#         3.94051553e-02,  5.48654178e-02,  3.14573653e-01,  1.88272789e-01,
#         3.12106718e-01,  3.49399864e-02, -1.85201954e-01,  1.26004340e-01,
#         4.57471516e-02,  9.96949383e-02,  4.14993140e-01,  5.72169564e-02,
#         2.16783652e+00,  6.38866649e-02,  1.43772440e-01,  9.45791285e-01,
#         4.26406327e-02, -3.34127045e-01,  6.25400030e-02,  1.17305965e+00,
#        -8.44592912e-03, -6.32501688e-03,  9.14355450e-01, -1.80955467e-02,
#         2.20403868e-01,  2.06568372e-02,  1.36255978e-01,  4.70284444e-02,
#        -5.81978701e-02,  2.26080440e-01,  2.73174391e-02,  8.91538044e-02,
#         6.55919337e-02, -7.61197738e-03,  2.77062041e-01,  1.56587227e-02,
#         8.00827989e-02, -1.44693978e-01,  9.91379442e-02, -1.85833703e-03,
#         3.69894450e-02,  6.53744884e-02,  2.51487686e-01,  2.74622057e-01,
#         7.08699045e-02,  3.25862702e-01,  5.34334753e-02, -6.88181967e-02,
#         5.95213649e-02,  1.51647415e-01,  3.98328810e-01,  9.63585270e-01,
#         6.64368566e-02,  6.16067056e-02, -1.17015381e-02, -1.39079311e-02,
#         3.91435877e-01,  3.54039123e-02,  3.28186831e-02, -3.86797833e-02,
#         1.07686124e-01,  2.59782139e-02,  2.26311375e-01,  5.40811739e-02,
#        -1.09412465e-01,  1.06369508e-01,  5.22675097e-02, -9.96107811e-03,
#         5.65671611e-01, -2.50115920e-02,  1.34356374e-01,  5.08128722e-02,
#         5.55851768e-02,  1.81715449e-01,  1.93513209e-01,  2.38180472e-01,
#         6.49953475e-02,  2.15308077e-01, -1.68732833e-01,  9.23050072e-02,
#        -9.25011372e-02, -7.95539129e-02,  6.24431503e-02,  7.38517894e-02,
#         2.10898526e-01,  2.14312327e-01,  7.91790055e-02,  1.40811994e-01,
#        -6.48031666e-02,  2.36915542e-03,  1.22171027e-01,  3.22400138e-01,
